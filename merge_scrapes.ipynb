# %% [markdown]
# # Merge Scrapes
# Start by importing some utilities and the raw data:

# %%
import jupyterImport
jupyterImport.enableJupyterImports()
from Utilities import find, genSamples, genSample, pluck, copyKeys, MultiReplace, allWith, analyze
from parse_q import reports, comments
from my_harvard_map import offerings
from copy import deepcopy

# %% [markdown]
# First, we need to link `offerings` and `reports` together. All we can really do is match `group + number` combinations. We'll need to manually account for group / department names that have changed over time. We should have those on this list:

# %%
groupReplace = MultiReplace({
  'AM-CIV': 'AMSTDIES',
  'CL': 'COMPLIT',
  'DRAMA': 'TDM',
  'HINDI': 'HIND-URD',
  'HUMFRAME': 'HUMAN',
  'HUMQSTNS': 'HUMAN',
  'IMUIL': 'IMMUN',
  'IRANCIV': 'IRANIAN',
  'LIT': 'COMPLIT,ENGLISH',
  'LITER': 'COMPLIT,ENGLISH',
  'LITERTRE': 'COMPLIT,ENGLISH',
  'MOR-REAS': 'ETHRSON',
  'PAL': 'PALI',
  'QNT-REAS': 'EMREAS',
  'SANSKRT': 'SANSKRIT',
  'SCIENCE': 'SCIPHUNV,SCILIVSY',
  'SOC-ANAL': 'SOCWORLD',
  'TAMIL': 'TAM',
  'TIBETAN': 'TIBET',
  'TIBHIST': 'TIBET',
  'URD': 'HIND-URD',
  'URDU': 'HIND-URD'
})

# %% [markdown]
# Which was figured out with the following:

# %%
### Run to inspect
qRepsByGroup = []
from collections import defaultdict
reportsByGroup = defaultdict(list)
for report, group in allWith('group', reports):
  reportsByGroup[group].append(report)
for key, reps in sorted(reportsByGroup.items()):
  srted = sorted([year for _, year in allWith('year', reps)], reverse=True)
  qRepsByGroup.append(' '.join([key, srted[0], str(len(reps)), reps[0]['title']]))
qRepsByGroup
# Out:
# [u'AESTHINT 2016 135 Modern Jewish Literature',
#  u'AFRAMER 2016 489 Malagasy',
#  u'AKKAD 2016 9 Intermediate Babylonian',
#  u'AM-CIV 2012 6 Major Works in the History of American Civilization',
#  u'AMSTDIES 2016 5 Hyphen-Nation',
#  u'ANE 2016 26 The History and Archaeology of Jerusalem',
#  u'ANTHRO 2016 519 Junior Tutorial in Social Anthropology',
#  u'APCOMP 2016 20 Computational Fluid Dynamics',
#  u'APMTH 2016 189 Mathematical Methods in the Sciences',
#  u'APPHY 2016 103 Introduction to Solid State Physics',
#  u'ARABIC 2016 154 Elementary Arabic',
#  u'ARAMAIC 2012 3 Introduction to Babylonian Aramaic',
#  u'ARMEN 2016 1 Elementary Modern Eastern Armenian',
#  u'ARMENST 2016 1 Armenian Literature in Translation',
#  u'ASTRON 2016 182 Radiative Processes in Astrophysics',
#  u'BBS 2016 16 Analysis of the Biological Literature',
#  u'BCMP 2016 81 Principles of Human Disease',
#  u'BCS 2016 16 Elementary Bosnian/Croatian/Serbian',
#  u'BE 2016 19 Cellular Engineering',
#  u'BIOLOGY 2007 5 Behavioral Ecology',
#  u'BIOLSCI 2007 1 Animal Behavior',
#  u'BIOPHYS 2016 24 Quantitative Genomics',
#  u'BIOSTAT 2016 128 Statistical Inference I',
#  u'BPH 2016 38 Biological Sciences Seminars',
#  u'BSDM 2009 2 Research with Faculty',
#  u'BUSSTUD 2012 1 Micro Topics in Organizational Behavior',
#  u'CATALAN 2015 6 Introduction to Catalan',
#  u'CELLBIO 2016 74 Vertebrate Developmental and Regenerative Biology',
#  u'CELTIC 2016 81 Early Irish Historical Tales',
#  u'CHEM 2016 246 Experimental Physical Chemistry',
#  u'CHEMBIO 2016 15 Introduction to Chemical Biology II',
#  u'CHNSE 2016 219 Intermediate Literary Chinese',
#  u'CHNSHIS 2016 43 History of Relations between China and Inner Asia',
#  u'CHNSLING 2010 1 Introduction to Teaching of Modern Chinese Language',
#  u'CHNSLIT 2016 64 Gender and Power in Chinese Literature',
#  u'CL 2012 21 Approaches to Modernity',
#  u'CLAS-HEB 2013 6 Elementary Classical Hebrew',
#  u'CLASARCH 2016 27 Introduction to Greek Art and Archaeology, ca. 1200-300 BCE',
#  u'CLASPHIL 2016 48 Lucretius',
#  u'CLASSIC 2016 27 Tutorial - Junior Year',
#  u'CLS-STDY 2016 61 Greek Culture and Civilization',
#  u'COMPLIT 2016 68 Renaissance and Baroque Drama',
#  u'COMPSCI 2016 354 Data Structures and Algorithms',
#  u'CPB 2016 5 Laboratory Research for Honors Thesis',
#  u'CULTBLF 2016 159 Back Roads to Far Places',
#  u'CZCH 2016 17 Elementary Czech',
#  u'DRAMA 2015 123 Group Choreography',
#  u'DRB 2016 8 Experimental Approaches to Developmental Biology',
#  u'DUTCH 2007 1 Elementary Dutch',
#  u'E-PSCI 2016 235 Field Experiences in Earth and Planetary Sciences',
#  u'EABS 2016 12 Chinese Buddhist Texts - Readings in Medieval Buddho-Daoist Documents',
#  u"EAFM 2016 22 Media Cultures in the People's Republic",
#  u'EASTD 2016 87 Junior Tutorial - The Study of East Asian Religions',
#  u'ECON 2016 1059 Economics of Discontinuous Change',
#  u'EDC 2009 4 The Quality of Health Care in America',
#  u'EGYPTIAN 2014 3 The Language of the Pharaohs',
#  u'EMR 2016 4 Native Americans in the 21st Century',
#  u'EMREAS 2016 39 Fat Chance',
#  u'ENG-SCI 2016 523 Engineering Thermodynamics',
#  u'ENGLISH 2016 863 Disfluency and Style',
#  u'ESPP 2016 78 Ecology and Land-Use Planning',
#  u'ETHRSON 2016 72 Medical Ethics and History',
#  u'EXPOS 2016 688 Public Speaking Practicum',
#  u'FOLKMYTH 2016 66 Continuing Oral Traditions in Indigenous Communities',
#  u'FOR-CULT 2011 39 Popular Culture in Modern China',
#  u'FRENCH 2016 343 Aim\xe9 C\xe9saire and His Others',
#  u'FRSEMR 2016 1190 Human Rights Between Rhetoric and Reality',
#  u'GENETIC 2016 63 Advanced Topics in Gene Expression',
#  u'GERM-STD 2013 1 Germanic Mythology',
#  u'GERMAN 2016 197 Intermediate German',
#  u'GERMPHIL 2014 1 Middle High German',
#  u'GHHP 2016 20 Negotiation and Conflict Management',
#  u'GIKUYU 2016 3 Reading in Gikuyu',
#  u"GOV 2016 974 Rousseau's Political Thought",
#  u'GREEK 2016 117 Beginning Greek',
#  u'HAA 2016 345 Landmarks of World Art & Architecture',
#  u'HBTM 2016 29 Principles of Human Disease',
#  u'HEB 2016 194 Walk This Way',
#  u'HEBREW 2016 12 Song at the Sea',
#  u'HIND-URD 2016 28 Advanced Hindi-Urdu',
#  u'HINDI 2011 2  Intensive Introductory Hindi',
#  u'HIS-STD 2010 52 The Modern World Economy, 1873-2000',
#  u'HIST 2016 1007 Secularization in Europe and the United States, c. 1780-2000',
#  u'HIST-LIT 2016 117 Early American Environments',
#  u'HISTSCI 2016 357 History of Science Salon',
#  u'HLTHPOL 2016 25 Federal Research Funding',
#  u'HSEMR-CU 2008 1 Medicine, Law, and Ethics',
#  u'HSEMR-EL 2008 1 Nutrition and Public Health',
#  u'HSEMR-LE 2016 6 Sigmund Freud and C. S. Lewis',
#  u'HSEMR-LO 2012 1 Perspectives about Undergraduate Learning',
#  u'HSEMR-MA 2011 2 Memoirs and Memory in 20th Century Europe',
#  u'HSEMR-PF 2012 3 College Student Development Theory',
#  u'HSEMR-WI 2016 8 The Laws of War',
#  u'HUMAN 2016 21 A Humanities Colloquium',
#  u'HUMFRAME 2015 3 Frameworks',
#  u'HUMQSTNS 2015 1 Human History',
#  u'IMMUN 2016 11 Cancer Immunology',
#  u'IMUIL 2015 63 Critical Readings for Immunology',
#  u'INDN-ST 2012 12 Reading and Research',
#  u'IRANCIV 2010 2 Beyond Good and Evil',
#  u'IRANIAN 2016 8 Introduction to Avestan',
#  u'IRISH 2016 25 Introduction to Old Irish',
#  u'ISLAMCIV 2016 30 The Satanic Verses',
#  u'ITAL 2016 172 Visions of the Renaissance',
#  u'JAPAN 2016 126 Elementary Japanese',
#  u'JAPNHIST 2016 36 Early Modern Japanese History',
#  u'JAPNLIT 2016 38 Haiku',
#  u'JEWISHST 2016 17 Jewish-Arab Encounters',
#  u'KOREAN 2016 109 Pre-advanced Korean',
#  u'KORHIST 2016 23 Modern Korean History',
#  u'KORLIT 2016 6 Modern Korean Poetry',
#  u'LAT-STD 2016 9 Modernity, Culture and Politics in Latin America',
#  u'LATIN 2016 161 History of Latin Literature II',
#  u'LIFESCI 2016 67 An Integrated Introduction to the Life Sciences',
#  u'LING 2016 190 Second Language Acquisition',
#  u'LIT 2012 4 Tutorial - Junior Year',
#  u'LIT-ART 2011 68 Russian Imperial Masterworks and Their Post-Histories',
#  u'LITER 2015 71 Fictional Encyclopedias',
#  u'LITERTRE 2013 36 Literature and Science',
#  u'LPS 2016 10 Foundational Chemistry and Biology',
#  u'MANCHU 2016 9 Elementary Manchu',
#  u'MATH 2016 658 Algebraic Topology',
#  u'MBB 2016 69 Love, Hate, and Play',
#  u'MCB 2016 318 Advanced Cell Biology',
#  u'MED-SCI 2016 13 Conduct of Science Refresher',
#  u"MEDGREEK 2016 12 Byzantine Saints' Lives of the 7th Century",
#  u'MEDLATIN 2016 13 Introduction to Medieval Latin Literature',
#  u'MEDVLSTD 2016 26 Authority and Invention',
#  u"MES 2013 1 Master's Thesis Reading and Research",
#  u'MICROBI 2016 39 Microbial Sciences',
#  u'MOD-HEB 2016 60 Intermediate Modern Hebrew II',
#  u'MODGRK 2016 60 Intermediate Modern Greek',
#  u'MODMDEST 2016 28 The Arab-Israeli Conflict',
#  u'MONGOLN 2014 1 Elementary Written Mongolian',
#  u'MOR-REAS 2010 19 Moral Reasoning about Social Protest',
#  u'MUSIC 2016 512 Topics in Orchestral Conducting',
#  u'NEC 2016 21 Middle Eastern Studies Research Project',
#  u'NEP 2016 15 Introductory Nepali',
#  u'NEPALI 2010 2 Advanced Nepali',
#  u'NEURO 2016 7 Laboratory Research',
#  u'NEUROBIO 2016 220 More than Glue',
#  u'NORWGN 2010 3 Beginning Norwegian Language',
#  u'OEB 2016 341 Comparative Biomechanics',
#  u'PAL 2013 2 Introductory Pali',
#  u'PALI 2014 3 Introductory Pali',
#  u'PATHOL 2011 2 Tumor Pathophysiology and Transport Phenomena - A Systems Biology Approach',
#  u'PERSIAN 2016 49 Elementary Persian',
#  u'PHIL 2016 339 Aristotle',
#  u'PHS 2016 1 Quantitative Research Methods in Population Health Sciences I',
#  u'PHYSCI 2016 46 Electromagnetism, Circuits, Waves, Optics, and Imaging',
#  u'PHYSICS 2016 409 Quantum Mechanics II',
#  u'PLSH 2016 16 Elementary Polish I',
#  u'PORTUG 2016 132 Themes of Enchantment, Radiance and Epiphany in Brazilian Culture',
#  u'PSY 2016 857 Social Psychology',
#  u'QNT-REAS 2010 16 Uncertainty and Statistical Reasoning',
#  u'RELIGION 2016 263 Kant and Enthusiasm',
#  u'ROM-LANG 2016 6 Seminar for Dissertation Writing in the Romance Literatures',
#  u'ROM-STD 2016 30 Fragments of a Material History of Literature',
#  u"RSRA 2016 12 Master's Thesis Reading and Research",
#  u'RUSS 2016 63 Advanced Russian I',
#  u'SALLC 2012 3 South Asian Language Tutorials',
#  u'SANSKRIT 2016 69 Intermediate Sanskrit II',
#  u'SANSKRT 2012 11 Advanced Literary Sanskrit',
#  u'SAS 2016 53 Class and the City in Indian Cinema',
#  u'SCAND 2016 53 Old Norse Language, Literature, and Culture',
#  u'SCIENCE 2010 44 The Nature of Light and Matter',
#  u'SCILIVSY 2016 69 Psychological Science',
#  u'SCIPHUNV 2016 83 Natural Disasters',
#  u'SCRB 2016 129 Human Developmental and Regenerative Biology',
#  u'SCTGALIC 2013 3 Introduction to Scottish Gaelic',
#  u'SEMPHIL 2008 1 Introduction to the Comparative Study of Semitic Languages',
#  u'SHBT 2016 35 Molecular Biology of the Auditory System',
#  u'SLAVIC 2016 296 Intermediate Czech I',
#  u'SOC-ANAL 2010 33 Urban Revolutions',
#  u'SOC-STD 2016 273 Introduction to Social Studies',
#  u'SOCIOL 2016 489 The News Media and the Political Process',
#  u'SOCWORLD 2016 141 Japan in Asia and the World',
#  u'SPANSH 2016 344 The Modern Era of Latin American Literature',
#  u'SPOL 2014 3 Introduction to Social Policy Research',
#  u'STAT 2016 376 Introduction to Probability',
#  u'SWAHILI 2016 55 Reading in Swahili II',
#  u'SWEDISH 2016 24 Beginning Swedish Language and Literature',
#  u'SYSBIO 2016 3 Biomolecular Engineering and Synthetic Biology',
#  u'SYSTBIO 2016 35 Studying Evolution through Models and Experiments',
#  u'TAM 2016 27 Elementary Tamil',
#  u'TAMIL 2012 1 Advanced Tamil',
#  u"TDM 2016 34 What's so Funny?",
#  u'THI 2016 24 Intermediate Thai II',
#  u'TIBET 2016 65 Intermediate Colloquial Tibetan',
#  u'TIBETAN 2013 15 History of Tibetology',
#  u'TIBHIST 2010 1 A Cultural and Political History',
#  u'TURKISH 2016 36 Advanced Turkish I',
#  u'TWI 2016 49 Elementary Twi',
#  u'UKRA 2016 12 Advanced Ukrainian',
#  u'UKRAN 2016 2 Ukrainian Studies',
#  u'UNKNOWN 2009 2 Tutorial - Junior Year',
#  u'URD 2014 38 Intermediate Urdu-Hindi',
#  u'URDU 2011 15 Introductory Urdu-Hindi',
#  u'US-WORLD 2016 91 Designing the American City',
#  u'UYGHUR 2015 12 Elementary Uyghur',
#  u'VES 2016 602 Modernization in the Visual United States Environment, 1890-2035',
#  u'VIETNAM 2016 37 Advanced Vietnamese',
#  u'VIROLOGY 2016 35 Animal Virology',
#  u'WELSH 2016 21 Seminar',
#  u'WOMGEN 2016 195 Beyond the Sound Bite',
#  u'YIDDISH 2014 10 Modern Yiddish Literature',
#  u'YORUBA 2016 55 Intermediate Yoruba']

# %% [markdown]
# Now we can match and assign `reports` to each `offering` that has them.

# %%
from collections import defaultdict
from operator import itemgetter

def buildQMatchTable(reports):
  qLookup = defaultdict(list)
  for report in reports:
    report['number'] = report['number'].split('.')[0] if report['group'] == 'EXPOS' else report['number']
    groups = groupReplace.sub(report['group']).split(',')
    for group in groups:
      qLookup[group + report['number']].append(report)
  return qLookup
    
def topReport(offering, reports):
  if 'profs' not in offering:
    reports[0]['relevantBecause'] = 'mostRecent'
    return reports[0], reports[1:]
  for profIndex, matchName in enumerate([prof['matchName'] for prof in offering['profs']]):
    for repI, report in enumerate(reports):
      if 'profs' not in report:
        continue
      for _ in [qProf for qProf in report['profs'] if qProf['matchName'] == matchName]:
        top = report
        top.update({'relevantBecause': 'profMatch_index=' + str(profIndex), 'matched': matchName})
        return top, reports[0:repI] + reports[repI+1:len(reports)]
  reports[0]['relevantBecause'] = 'mostRecent'
  return reports[0], reports[1:]

def linkReportsToOfferings(reports, offerings):
  qLookup = buildQMatchTable(reports)
  for offering in offerings:
    reports = qLookup[offering['group'] + offering['number']]
    if not reports:
      continue
    if offering['group'] == 'EXPOS':
      names = set([p['matchName'] for p in offering['profs']] if 'profs' in offering else [])
      newReports = []
      for report, profs in allWith('profs', reports):
        profs = [p for p in profs if p['matchName'] in names]
        if len(profs) > 0:
          newReport = deepcopy(report)
          newReport['profs'] = profs
          newReports.append(newReport)
      reports = newReports
      if len(reports) == 0:
        continue
    for report in reports:
      report['group'] = offering['group']
    reports.sort(key=itemgetter('term'))
    reports.sort(key=itemgetter('year'), reverse=True)
    top, rest = topReport(offering, reports)
    offering['topReport'] = top
    if len(rest) > 0:
      offering['reports'] = rest

# %%
linkReportsToOfferings(reports, offerings)

# %%
import operator

def getPrimaryReason(offering):
  try:
    primaryReason = sorted(offering['topReport']['reasons'].items(), key=operator.itemgetter(1)).pop()[0]
  except:
    return {}
  displayMap = {
    'elective': 'Elective',
    'concentration': 'Concentration',
    'secondary': 'Secondary or Citation',
    'genEd': 'Gen Ed',
    'expos': 'Expos',
    'language': 'Language',
    'preMed': 'Pre-Med'
  }
  return {'primaryReason': displayMap[primaryReason]}

# %%
for offering, topReport in allWith('topReport', offerings):
  primaryReason = getPrimaryReason(offering)
  offering.update(primaryReason)
